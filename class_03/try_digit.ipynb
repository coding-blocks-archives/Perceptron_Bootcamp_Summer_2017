# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_csv('../train.csv')

# %%
d = data.values
print d.shape
# Out:
# (42000, 785)

# %%
my_data = d[:5000, 1:]

# %%
plt.figure(0)

plt.imshow(my_data[:, :].mean(axis=0).reshape((28, 28)), cmap='gray', interpolation='none')
plt.show()

# %%
f1 = np.load('./face_01.npy')
f2 = np.load('./face_02.npy')

print f1.shape, f2.shape
# Out:
# (10, 64, 64, 3) (10, 64, 64, 3)

# %%
import cv2

# %%
plt.figure(0)

plt.imshow(cv2.cvtColor(f2[3, :], cv2.COLOR_BGR2RGB))
plt.show()
